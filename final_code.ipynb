# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten,BatchNormalization
from tensorflow.keras.layers import Conv2D,MaxPooling2D
import os

# %%
num_classes = 7
img_rows,img_cols = 48,48
batch_size = 32

train_data_dir = r'C:\Users\91996\Desktop\ML\face-detection\images/train'
validation_data_dir = r'C:\Users\91996\Desktop\ML\face-detection\images/validation'

train_datagen = ImageDataGenerator(
rescale=1./255,
rotation_range=30,
shear_range=0.3,
zoom_range=0.3,
width_shift_range=0.4,
height_shift_range=0.4,
horizontal_flip=True,
fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
train_data_dir,
color_mode='grayscale',
target_size=(img_rows,img_cols),
batch_size=batch_size,
class_mode='categorical',
shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
validation_data_dir,
color_mode='grayscale',
target_size=(img_rows,img_cols),
batch_size=batch_size,
class_mode='categorical',
shuffle=True)


model = Sequential()

# Block-1

model.add(Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(img_rows,img_cols,1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(img_rows,img_cols,1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-2 

model.add(Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-3

model.add(Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-4 

model.add(Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-5

model.add(Flatten())
model.add(Dense(64,kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-6

model.add(Dense(64,kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-7

model.add(Dense(num_classes,kernel_initializer='he_normal'))
model.add(Activation('softmax'))

print(model.summary())
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 48, 48, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 24, 24, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 24, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 256)         295168
# _________________________________________________________________
# activation_6 (Activation)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 256)         590080
# _________________________________________________________________
# activation_7 (Activation)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                147520
# _________________________________________________________________
# activation_8 (Activation)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# activation_9 (Activation)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# _________________________________________________________________
# activation_10 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 1,328,167
# Trainable params: 1,325,991
# Non-trainable params: 2,176
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint(r'C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

callbacks = [earlystop,checkpoint,reduce_lr]

model.compile(loss='categorical_crossentropy',
              optimizer = Adam(lr=0.001),
              metrics=['accuracy'])

nb_train_samples = 24176
nb_validation_samples = 3006
epochs=25

history=model.fit(
                train_generator,
                steps_per_epoch=nb_train_samples//batch_size,
                epochs=epochs,
                callbacks=callbacks,
                validation_data=validation_generator,
                validation_steps=nb_validation_samples//batch_size)
# Out:
# Epoch 1/25
# 753/755 [============================>.] - ETA: 0s - loss: 1.8605 - accuracy: 0.2188 ETA: 0s - loss:
# Epoch 00001: val_loss improved from inf to 1.79902, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 25s 33ms/step - loss: 1.8604 - accuracy: 0.2191 - val_loss: 1.7990 - val_accuracy: 0.2571
# Epoch 2/25
# 755/755 [==============================] - ETA: 0s - loss: 1.8019 - accuracy: 0.2469
# Epoch 00002: val_loss did not improve from 1.79902
# 755/755 [==============================] - 22s 29ms/step - loss: 1.8019 - accuracy: 0.2469 - val_loss: 1.8116 - val_accuracy: 0.2308
# Epoch 3/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.7903 - accuracy: 0.2558
# Epoch 00003: val_loss improved from 1.79902 to 1.72430, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 22s 29ms/step - loss: 1.7905 - accuracy: 0.2557 - val_loss: 1.7243 - val_accuracy: 0.2893
# Epoch 4/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.7536 - accuracy: 0.2753
# Epoch 00004: val_loss did not improve from 1.72430
# 755/755 [==============================] - 22s 29ms/step - loss: 1.7536 - accuracy: 0.2753 - val_loss: 1.8076 - val_accuracy: 0.2665
# Epoch 5/25
# 755/755 [==============================] - ETA: 0s - loss: 1.7083 - accuracy: 0.3022
# Epoch 00005: val_loss improved from 1.72430 to 1.59200, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 22s 30ms/step - loss: 1.7083 - accuracy: 0.3022 - val_loss: 1.5920 - val_accuracy: 0.3767
# Epoch 6/25
# 755/755 [==============================] - ETA: 0s - loss: 1.6476 - accuracy: 0.3431
# Epoch 00006: val_loss improved from 1.59200 to 1.48691, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 23s 31ms/step - loss: 1.6476 - accuracy: 0.3431 - val_loss: 1.4869 - val_accuracy: 0.4382
# Epoch 7/25
# 755/755 [==============================] - ETA: 0s - loss: 1.5832 - accuracy: 0.3783
# Epoch 00007: val_loss improved from 1.48691 to 1.35682, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 24s 31ms/step - loss: 1.5832 - accuracy: 0.3783 - val_loss: 1.3568 - val_accuracy: 0.4963
# Epoch 8/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.5288 - accuracy: 0.4057
# Epoch 00008: val_loss improved from 1.35682 to 1.33394, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 24s 31ms/step - loss: 1.5289 - accuracy: 0.4056 - val_loss: 1.3339 - val_accuracy: 0.4933
# Epoch 9/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.4825 - accuracy: 0.4316
# Epoch 00009: val_loss improved from 1.33394 to 1.29753, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 24s 32ms/step - loss: 1.4824 - accuracy: 0.4316 - val_loss: 1.2975 - val_accuracy: 0.5134
# Epoch 10/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.4566 - accuracy: 0.4397
# Epoch 00010: val_loss improved from 1.29753 to 1.21508, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 25s 33ms/step - loss: 1.4565 - accuracy: 0.4397 - val_loss: 1.2151 - val_accuracy: 0.5349
# Epoch 11/25
# 755/755 [==============================] - ETA: 0s - loss: 1.4354 - accuracy: 0.4490 ETA: 0s - loss: 1.4340 - accu
# Epoch 00011: val_loss did not improve from 1.21508
# 755/755 [==============================] - 24s 32ms/step - loss: 1.4354 - accuracy: 0.4490 - val_loss: 1.2594 - val_accuracy: 0.5060
# Epoch 12/25
# 755/755 [==============================] - ETA: 0s - loss: 1.4158 - accuracy: 0.4588
# Epoch 00012: val_loss improved from 1.21508 to 1.19912, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 27s 35ms/step - loss: 1.4158 - accuracy: 0.4588 - val_loss: 1.1991 - val_accuracy: 0.5464
# Epoch 13/25
# 755/755 [==============================] - ETA: 0s - loss: 1.4015 - accuracy: 0.4665
# Epoch 00013: val_loss did not improve from 1.19912
# 755/755 [==============================] - 26s 34ms/step - loss: 1.4015 - accuracy: 0.4665 - val_loss: 1.2042 - val_accuracy: 0.5417
# Epoch 14/25
# 755/755 [==============================] - ETA: 0s - loss: 1.3898 - accuracy: 0.4677
# Epoch 00014: val_loss improved from 1.19912 to 1.15839, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 27s 35ms/step - loss: 1.3898 - accuracy: 0.4677 - val_loss: 1.1584 - val_accuracy: 0.5655
# Epoch 15/25
# 755/755 [==============================] - ETA: 0s - loss: 1.3765 - accuracy: 0.4763 ETA: 0s - los
# Epoch 00015: val_loss did not improve from 1.15839
# 755/755 [==============================] - 26s 34ms/step - loss: 1.3765 - accuracy: 0.4763 - val_loss: 1.1722 - val_accuracy: 0.5433
# Epoch 16/25
# 755/755 [==============================] - ETA: 0s - loss: 1.3647 - accuracy: 0.48 - ETA: 0s - loss: 1.3648 - accuracy: 0.4808
# Epoch 00016: val_loss did not improve from 1.15839
# 755/755 [==============================] - 27s 35ms/step - loss: 1.3648 - accuracy: 0.4808 - val_loss: 1.1727 - val_accuracy: 0.5464
# Epoch 17/25
# 755/755 [==============================] - ETA: 0s - loss: 1.3534 - accuracy: 0.4846
# Epoch 00017: val_loss improved from 1.15839 to 1.13953, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 26s 35ms/step - loss: 1.3534 - accuracy: 0.4846 - val_loss: 1.1395 - val_accuracy: 0.5645
# Epoch 18/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.3413 - accuracy: 0.48 - ETA: 0s - loss: 1.3416 - accuracy: 0.4897
# Epoch 00018: val_loss did not improve from 1.13953
# 755/755 [==============================] - 27s 35ms/step - loss: 1.3416 - accuracy: 0.4898 - val_loss: 1.1500 - val_accuracy: 0.5568
# Epoch 19/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.3321 - accuracy: 0.4970
# Epoch 00019: val_loss improved from 1.13953 to 1.13790, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 27s 36ms/step - loss: 1.3323 - accuracy: 0.4970 - val_loss: 1.1379 - val_accuracy: 0.5689
# Epoch 20/25
# 755/755 [==============================] - ETA: 0s - loss: 1.3293 - accuracy: 0.4967
# Epoch 00020: val_loss did not improve from 1.13790
# 755/755 [==============================] - 27s 36ms/step - loss: 1.3293 - accuracy: 0.4967 - val_loss: 1.1774 - val_accuracy: 0.5605
# Epoch 21/25
# 755/755 [==============================] - ETA: 0s - loss: 1.3221 - accuracy: 0.5020
# Epoch 00021: val_loss improved from 1.13790 to 1.08465, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 27s 36ms/step - loss: 1.3221 - accuracy: 0.5020 - val_loss: 1.0847 - val_accuracy: 0.5968
# Epoch 22/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.3132 - accuracy: 0.5048
# Epoch 00022: val_loss improved from 1.08465 to 1.07670, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 28s 37ms/step - loss: 1.3132 - accuracy: 0.5048 - val_loss: 1.0767 - val_accuracy: 0.5890
# Epoch 23/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.3099 - accuracy: 0.5065
# Epoch 00023: val_loss improved from 1.07670 to 1.06263, saving model to C:\Users\91996\Desktop\ML\face-detection\Emotion_little_vgg.h5
# 755/755 [==============================] - 29s 38ms/step - loss: 1.3098 - accuracy: 0.5065 - val_loss: 1.0626 - val_accuracy: 0.5991
# Epoch 24/25
# 754/755 [============================>.] - ETA: 0s - loss: 1.2990 - accuracy: 0.5064
# Epoch 00024: val_loss did not improve from 1.06263
# 755/755 [==============================] - 30s 39ms/step - loss: 1.2990 - accuracy: 0.5064 - val_loss: 1.0774 - val_accuracy: 0.5911
# Epoch 25/25
# 755/755 [==============================] - ETA: 0s - loss: 1.2879 - accuracy: 0.5174
# Epoch 00025: val_loss did not improve from 1.06263
# 755/755 [==============================] - 29s 39ms/step - loss: 1.2879 - accuracy: 0.5174 - val_loss: 1.0668 - val_accuracy: 0.6011
